# %%
import pandas as pd

# %%
df = pd.read_excel('https://github.com/adan-rs/AnalisisDatos/raw/main/otros/prep2.xlsx')

# %%
df
# Out:
#             CLAVE_ACTA         ENTIDAD DISTRITO_FEDERAL  SECCION TIPO_CASILLA  \
# 0       '010000M01009'  AGUASCALIENTES              NaN      NaN            M
# 1       '010338B01001'  AGUASCALIENTES      Jesus Maria    338.0            B
# 2       '010338C01001'  AGUASCALIENTES      Jesus Maria    338.0            C
# 3       '010338C02001'  AGUASCALIENTES      Jesus Maria    338.0            C
# 4       '010339B01001'  AGUASCALIENTES      Jesus Maria    339.0            B
# ...                ...             ...              ...      ...          ...
# 170643  '321947C01001'       ZACATECAS        Guadalupe   1947.0            C
# 170644  '321947C02001'       ZACATECAS        Guadalupe   1947.0            C
# 170645  '321948B01001'       ZACATECAS        Guadalupe   1948.0            B
# 170646  '321948C01001'       ZACATECAS        Guadalupe   1948.0            C
# 170647  '321948C02001'       ZACATECAS        Guadalupe   1948.0            C
#
# ...
